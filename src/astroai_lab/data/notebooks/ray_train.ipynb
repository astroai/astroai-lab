# %% [markdown]
# # AstroAI + Ray (optional)
#
# Use the **stock Ray Dashboard** from a `ray-manager` session. This notebook is a student-facing sketch — it does not start a cluster by itself.
#
# 1. Laptop/portal: launch `ray-manager` (or `canfar create contributed images.canfar.net/astroai/ray-manager:latest`)
# 2. Open the session URL → Ray Dashboard
# 3. Attach workers via the documented `canfar` headless flow (see containers `docs/RAY.md`)
# 4. Submit jobs with `ray` / `astroai-workload` from a driver notebook or project

# %%
# Example only — requires an existing Ray cluster address.
# import ray
# ray.init(address="auto")
# print(ray.cluster_resources())
print("See /opt/astroai/USAGE.md and docs/RAY.md for the launch path.")
